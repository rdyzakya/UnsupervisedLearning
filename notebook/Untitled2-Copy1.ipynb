# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.append('../')
import src.kmedoids as km

# %%
df = pd.read_csv('../datasets/kmeans_kmedoids/xclara.csv')

# %%
df.head()
# Out:
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %%
clf = km.KMedoidClustering()

# %%
clf.train(df,[0,1],3)
# Out:
# 54.79727554321289

# %%
clf.df.Label.value_counts()
# Out:
# 1    1149
# 0     952
# 2     899
# Name: Label, dtype: int64

# %%
plt.scatter(x = df['V1'], y = df['V2'])
plt.show()

# %%
colormap = np.array(['r', 'g', 'b'])
labels = np.array(clf.df.Label)
plt.scatter(x = clf.df['V1'], y = clf.df['V2'], c=colormap[labels])
plt.show()

# %%
clf.medoids
# Out:
#          V1         V2
# 0  69.85361  -9.066127
# 1  40.83747  60.211980
# 2   9.35213  10.424270

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

c = np.abs(a-b)

# %%
c
# Out:
# array([3, 3, 3])

# %%
np.array(df.loc[0])
# Out:
# array([ 2.072345, -3.241693])

# %%
np.array(df.loc[0]).sum()
# Out:
# -1.1693480000000003

# %%
2.072345 -3.241693
# Out:
# -1.1693480000000003

# %%
df.values
# Out:
# array([[  2.072345,  -3.241693],
#        [ 17.93671 ,  15.78481 ],
#        [  1.083576,   7.319176],
#        ...,
#        [ 64.46532 , -10.50136 ],
#        [ 90.72282 , -12.25584 ],
#        [ 64.87976 , -24.87731 ]])

# %%
df
# Out:
#              V1         V2
# 0      2.072345  -3.241693
# 1     17.936710  15.784810
# 2      1.083576   7.319176
# 3     11.120670  14.406780
# 4     23.711550   2.557729
# ...         ...        ...
# 2995  85.652800  -6.461061
# 2996  82.770880  -2.373299
# 2997  64.465320 -10.501360
# 2998  90.722820 -12.255840
# 2999  64.879760 -24.877310
#
# [3000 rows x 2 columns]

# %%
df.loc[0].values.sum()
# Out:
# -1.1693480000000003

# %%
df[df['V1'] == 0]
# Out:
# Empty DataFrame
# Columns: [V1, V2]
# Index: []

# %%
import time

# %%
start = time.time()
0 in df['V1'].unique()
time.time() - start
# Out:
# 0.0009963512420654297

# %%
df[df['V1'] == 0].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-242a12e34568> in <module>
# ----> 1 df[df['V1'] == 0].iloc[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
df
# Out:
#              V1         V2
# 0      2.072345  -3.241693
# 1     17.936710  15.784810
# 2      1.083576   7.319176
# 3     11.120670  14.406780
# 4     23.711550   2.557729
# ...         ...        ...
# 2995  85.652800  -6.461061
# 2996  82.770880  -2.373299
# 2997  64.465320 -10.501360
# 2998  90.722820 -12.255840
# 2999  64.879760 -24.877310
#
# [3000 rows x 2 columns]

# %%
df[df['V1'] == 0].index[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-60eae60926ea> in <module>
# ----> 1 df[df['V1'] == 0].index[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
a = df.loc[df['V1'] < 0]

# %%
a.index[0]
# Out:
# 13
