# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as skd

# %%
x,y = skd.make_circles(5000)#,noise=0.1,random_state=100,shuffle=True)

# %%
df = pd.DataFrame(x)

# %%
plt.scatter(x=df[0],y=df[1])
plt.show()

# %%
import sys
sys.path.append('../')
import src.dbscan as dbs

# %%
clf = dbs.DBScanClustering()

# %%
clf.train(df,[0,1],0.01,5)

# %%
clf.df.Label.unique()
# Out:
# array([0, 1])

# %%
clf.df.Label = clf.df.Label.astype(int)
clf.df.Label
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 495   -1
# 496   -1
# 497   -1
# 498   -1
# 499   -1
# Name: Label, Length: 500, dtype: int32

# %%
colormap = np.array(['r','b'])#, 'b', 'y', 'black'])
label = np.array(clf.df.Label)
plt.scatter(x=clf.df[0],y=clf.df[1],c=colormap[label])
plt.show()

# %%
colormap = np.array(['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#934434','#ffeff2'])
labels = np.array(clf.df.Label)
plt.scatter(x = clf.df[0], y = clf.df[1], c=colormap[labels])
plt.show()

# %%
class uhu:
    def __init__(self,val=1):
        self.val = val
    
    def ha(self,v):
        self.val = v
    
    def copy(self):
        return uhu(self.val)

# %%
a = uhu()

# %%
b = a.copy()
b.ha(200)
a.val
# Out:
# 1
